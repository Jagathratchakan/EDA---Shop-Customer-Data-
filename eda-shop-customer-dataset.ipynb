# %% [markdown]
# <a href="https://www.kaggle.com/code/jagathratchakan/eda-shop-customer-dataset?scriptVersionId=137461807" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %% [markdown]
# ** Tasks based on the Understanding of Customer dataset **
#
# ToDO 1 : Find the which gender mostly spending money based on the Spending Score and How much percentage they spent form their income.
#
# ToDO 2 : Visualize the profession counts based on the gender

# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv("/kaggle/input/customers-dataset/Customers.csv")
data.head(5)
# Out:
#    CustomerID  Gender  Age  Annual Income ($)  Spending Score (1-100)  \
# 0           1    Male   19              15000                      39
# 1           2    Male   21              35000                      81
# 2           3  Female   20              86000                       6
# 3           4  Female   23              59000                      77
# 4           5  Female   31              38000                      40
#
#       Profession  Work Experience  Family Size
# 0     Healthcare                1            4
# 1       Engineer                3            3
# 2       Engineer                1            1
# 3         Lawyer                0            2
# 4  Entertainment                2            6

# %%
### Info of the Customer Dataset

data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 8 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   CustomerID              2000 non-null   int64
#  1   Gender                  2000 non-null   object
#  2   Age                     2000 non-null   int64
#  3   Annual Income ($)       2000 non-null   int64
#  4   Spending Score (1-100)  2000 non-null   int64
#  5   Profession              1965 non-null   object
#  6   Work Experience         2000 non-null   int64
#  7   Family Size             2000 non-null   int64
# dtypes: int64(6), object(2)
# memory usage: 125.1+ KB

# %%
#Check Whether NULL values present in the data

print("Number of Null Values in the data set based on the column based : \n")
data.isnull().sum()
# Out:
# Number of Null Values in the data set based on the column based :
# CustomerID                 0
# Gender                     0
# Age                        0
# Annual Income ($)          0
# Spending Score (1-100)     0
# Profession                35
# Work Experience            0
# Family Size                0
# dtype: int64

# %%
# Drop the NULL value field in the dataset

new_data = data.dropna()
new_data.isnull().sum()
# Out:
# CustomerID                0
# Gender                    0
# Age                       0
# Annual Income ($)         0
# Spending Score (1-100)    0
# Profession                0
# Work Experience           0
# Family Size               0
# dtype: int64

# %%
print("Profession Hight Pay :\n")
top_area = new_data.groupby('Profession').agg({"Annual Income ($)":"max"})
print(top_area)
# Out:
# Profession Hight Pay :
#
#                Annual Income ($)
# Profession
# Artist                    189709
# Doctor                    189672
# Engineer                  189974
# Entertainment             186882
# Executive                 189630
# Healthcare                189689
# Homemaker                 188696
# Lawyer                    189650
# Marketing                 186069

# %%
#Number of MALE and FEMALE Workers
sns.countplot(x=new_data["Gender"])
# Out:
# <AxesSubplot:xlabel='Gender', ylabel='count'>

# %%
# Number of Male and Female Professions based on the field
plt.figure(figsize=(20,15),dpi=200)
sns.countplot(data = new_data,x="Profession",hue="Gender")
# Out:
# <AxesSubplot:xlabel='Profession', ylabel='count'>

# %%
# Profession Counts
new_data["Profession"].value_counts()
# Out:
# Artist           612
# Healthcare       339
# Entertainment    234
# Engineer         179
# Doctor           161
# Executive        153
# Lawyer           142
# Marketing         85
# Homemaker         60
# Name: Profession, dtype: int64

# %%
# Age based Count
print(new_data["Age"].value_counts())
print("\n\n Unique values in the age column : ",len(new_data["Age"].unique()))
# Out:
# 31    31
# 32    30
# 52    29
# 54    28
# 91    28
#       ..
# 71    12
# 61    11
# 10    11
# 42    11
# 98     9
# Name: Age, Length: 100, dtype: int64
#
#
#  Unique values in the age column :  100

# %%
### Count Plot based on the Age and Gender
plt.figure(figsize=(30,15),dpi=200)
sns.countplot(data = new_data,x="Age",hue="Gender")
# Out:
# <AxesSubplot:xlabel='Age', ylabel='count'>

# %%
### Spending Score based on the Male and Female Count
print("\n\n Unique values in the Spending Score column : ",len(new_data["Spending Score (1-100)"].unique()))

plt.figure(figsize=(30,15),dpi=200)
sns.countplot(data = new_data,x="Spending Score (1-100)",hue="Gender")
# Out:
#  Unique values in the Spending Score column :  101
# <AxesSubplot:xlabel='Spending Score (1-100)', ylabel='count'>

# %%
#Relationship between Working Experience and Annual Income
print("\n\n Unique values in the Spending Score column : ",len(new_data["Work Experience"].unique()))
sns.lmplot(x='Age', y='Annual Income ($)', data=new_data)
# Out:
#  Unique values in the Spending Score column :  18

# %%
# Another Visualization package in the python
import plotly.express as px
fig = px.bar(new_data, x='Age', y='Annual Income ($)',color="Gender")
fig.show()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.18.0.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# <div>                            <div id="f7349237-4ab0-41cb-9356-87ea88833c6b" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("f7349237-4ab0-41cb-9356-87ea88833c6b")) {                    Plotly.newPlot(                        "f7349237-4ab0-41cb-9356-87ea88833c6b",                        [{"alignmentgroup":"True","hovertemplate":"Gender=Male<br>Age=%{x}<br>Annual Income ($)=%{y}<extra></extra>","legendgroup":"Male","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Male","offsetgroup":"Male","orientation":"v","showlegend":true,"textposition":"auto","x":[19,21,64,67,37,22,20,52,35,25,31,29,35,60,53,18,24,48,33,59,47,69,53,70,19,63,18,19,70,59,26,40,57,38,67,48,18,48,24,48,20,67,26,49,54,68,66,65,19,27,39,43,40,59,38,47,39,20,32,19,32,25,28,48,34,43,39,37,34,19,50,42,32,40,28,36,36,58,27,59,35,46,30,28,33,32,32,30,34,46,86,49,48,79,43,76,0,15,84,91,55,92,23,80,59,12,79,26,7,94,78,16,93,68,86,9,11,62,17,32,85,31,26,56,12,72,45,66,36,5,13,16,52,24,84,0,75,22,99,23,22,20,17,90,99,46,65,72,52,85,22,46,8,90,34,83,1,21,78,59,13,54,13,79,18,21,37,83,80,89,33,38,31,90,28,1,78,59,37,3,7,54,89,7,11,74,1,84,93,56,0,13,86,91,97,20,32,82,39,7,76,22,66,90,12,41,68,36,28,97,81,85,20,97,13,48,93,89,57,91,56,99,16,89,84,40,0,54,65,32,15,22,83,49,42,75,91,22,62,41,12,94,39,72,29,38,58,77,79,78,35,63,32,91,26,74,27,31,94,49,49,53,26,15,54,71,1,14,17,86,42,96,89,83,42,8,64,41,5,56,47,4,82,62,36,83,3,52,75,36,60,8,38,64,19,84,16,89,5,80,37,87,3,13,64,12,58,28,78,56,91,77,19,94,19,84,74,30,67,70,33,75,11,25,59,41,60,85,26,7,28,67,38,63,65,44,76,2,76,85,21,94,90,63,97,68,16,25,5,67,52,